# %% [markdown]
# <a href="https://colab.research.google.com/github/haithemml/examine-trends-and-patterns/blob/main/guess_the_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
def guess_number():
  target = random.randint(1, 100)
  print("Welcome to the game")
  print("I choose the number between 1 and 100, can you try this?")

  while True:
    try:
      guess = int(input("Enter the guess"))
      if guess < target:
        print("Your number is too small, try again")
      elif guess > target:
        print("Your number is too large, try again")
      else:
        print("Congratulations! You guessed the number.")
        break
    except ValueError:
            print("Please enter a valid number.")
